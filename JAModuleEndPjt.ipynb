# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
a1=pd.read_csv(r"C:\Users\ATJ FAMILY\Downloads\DSML\Jupyter notebook\Module End Project\myexcel - myexcel.csv.csv")
a1
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2     John Holland  Boston Celtics      30       SG   27  06-May     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  06-Mar     203
# 454      Raul Neto       Utah Jazz      25       PG   24  06-Jan     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  07-Mar     256
# 456    Jeff Withey       Utah Jazz      24        C   26     7-0     231
# 457       Priyanka       Utah Jazz      34        C   25  07-Mar     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
a1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      458 non-null    object
#  1   Team      458 non-null    object
#  2   Number    458 non-null    int64
#  3   Position  458 non-null    object
#  4   Age       458 non-null    int64
#  5   Height    458 non-null    object
#  6   Weight    458 non-null    int64
#  7   College   374 non-null    object
#  8   Salary    447 non-null    float64
# dtypes: float64(1), int64(3), object(5)
# memory usage: 32.3+ KB

# %%
a1.describe()
# Out:
#            Number         Age      Weight        Salary
# count  458.000000  458.000000  458.000000  4.470000e+02
# mean    17.713974   26.934498  221.543668  4.833970e+06
# std     15.966837    4.400128   26.343200  5.226620e+06
# min      0.000000   19.000000  161.000000  3.088800e+04
# 25%      5.000000   24.000000  200.000000  1.025210e+06
# 50%     13.000000   26.000000  220.000000  2.836186e+06
# 75%     25.000000   30.000000  240.000000  6.500000e+06
# max     99.000000   40.000000  307.000000  2.500000e+07

# %%
a1.describe(include="all")
# Out:
#                  Name                  Team      Number Position         Age  \
# count             458                   458  458.000000      458  458.000000
# unique            458                    30         NaN        5         NaN
# top     Avery Bradley  New Orleans Pelicans         NaN       SG         NaN
# freq                1                    19         NaN      102         NaN
# mean              NaN                   NaN   17.713974      NaN   26.934498
# std               NaN                   NaN   15.966837      NaN    4.400128
# min               NaN                   NaN    0.000000      NaN   19.000000
# 25%               NaN                   NaN    5.000000      NaN   24.000000
# 50%               NaN                   NaN   13.000000      NaN   26.000000
# 75%               NaN                   NaN   25.000000      NaN   30.000000
# max               NaN                   NaN   99.000000      NaN   40.000000
#
# ...

# %%
a1.shape
# Out:
# (458, 9)

# %%
a1.head(50)
# Out:
#                        Name                Team  Number Position  Age  Height  \
# 0             Avery Bradley      Boston Celtics       0       PG   25  06-Feb
# 1               Jae Crowder      Boston Celtics      99       SF   25  06-Jun
# 2              John Holland      Boston Celtics      30       SG   27  06-May
# 3               R.J. Hunter      Boston Celtics      28       SG   22  06-May
# 4             Jonas Jerebko      Boston Celtics       8       PF   29  06-Oct
# 5              Amir Johnson      Boston Celtics      90       PF   29  06-Sep
# 6             Jordan Mickey      Boston Celtics      55       PF   21  06-Aug
# 7              Kelly Olynyk      Boston Celtics      41        C   25     7-0
# 8              Terry Rozier      Boston Celtics      12       PG   22  06-Feb
# 9              Marcus Smart      Boston Celtics      36       PG   22  06-Apr
# 10          Jared Sullinger      Boston Celtics       7        C   24  06-Sep
# ...

# %%
a1.isnull()
# Out:
#       Name   Team  Number  Position    Age  Height  Weight  College  Salary
# 0    False  False   False     False  False   False   False    False   False
# 1    False  False   False     False  False   False   False    False   False
# 2    False  False   False     False  False   False   False    False    True
# 3    False  False   False     False  False   False   False    False   False
# 4    False  False   False     False  False   False   False     True   False
# ..     ...    ...     ...       ...    ...     ...     ...      ...     ...
# 453  False  False   False     False  False   False   False    False   False
# 454  False  False   False     False  False   False   False     True   False
# 455  False  False   False     False  False   False   False     True   False
# 456  False  False   False     False  False   False   False    False   False
# 457  False  False   False     False  False   False   False    False   False
#
# [458 rows x 9 columns]

# %%
a1.isnull().sum()
# Out:
# Name         0
# Team         0
# Number       0
# Position     0
# Age          0
# Height       0
# Weight       0
# College     84
# Salary      11
# dtype: int64

# %%
a1["Salary"].fillna(0,inplace=True)

# %%
a1.head(50)
# Out:
#                        Name                Team  Number Position  Age  Height  \
# 0             Avery Bradley      Boston Celtics       0       PG   25  06-Feb
# 1               Jae Crowder      Boston Celtics      99       SF   25  06-Jun
# 2              John Holland      Boston Celtics      30       SG   27  06-May
# 3               R.J. Hunter      Boston Celtics      28       SG   22  06-May
# 4             Jonas Jerebko      Boston Celtics       8       PF   29  06-Oct
# 5              Amir Johnson      Boston Celtics      90       PF   29  06-Sep
# 6             Jordan Mickey      Boston Celtics      55       PF   21  06-Aug
# 7              Kelly Olynyk      Boston Celtics      41        C   25     7-0
# 8              Terry Rozier      Boston Celtics      12       PG   22  06-Feb
# 9              Marcus Smart      Boston Celtics      36       PG   22  06-Apr
# 10          Jared Sullinger      Boston Celtics       7        C   24  06-Sep
# ...

# %%
a1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      458 non-null    object
#  1   Team      458 non-null    object
#  2   Number    458 non-null    int64
#  3   Position  458 non-null    object
#  4   Age       458 non-null    int64
#  5   Height    458 non-null    object
#  6   Weight    458 non-null    int64
#  7   College   374 non-null    object
#  8   Salary    458 non-null    float64
# dtypes: float64(1), int64(3), object(5)
# memory usage: 32.3+ KB

# %%
a1["College"].fillna("No College",inplace=True)

# %%
a1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      458 non-null    object
#  1   Team      458 non-null    object
#  2   Number    458 non-null    int64
#  3   Position  458 non-null    object
#  4   Age       458 non-null    int64
#  5   Height    458 non-null    object
#  6   Weight    458 non-null    int64
#  7   College   458 non-null    object
#  8   Salary    458 non-null    float64
# dtypes: float64(1), int64(3), object(5)
# memory usage: 32.3+ KB

# %%
a1.head(40)
# Out:
#                        Name             Team  Number Position  Age  Height  \
# 0             Avery Bradley   Boston Celtics       0       PG   25  06-Feb
# 1               Jae Crowder   Boston Celtics      99       SF   25  06-Jun
# 2              John Holland   Boston Celtics      30       SG   27  06-May
# 3               R.J. Hunter   Boston Celtics      28       SG   22  06-May
# 4             Jonas Jerebko   Boston Celtics       8       PF   29  06-Oct
# 5              Amir Johnson   Boston Celtics      90       PF   29  06-Sep
# 6             Jordan Mickey   Boston Celtics      55       PF   21  06-Aug
# 7              Kelly Olynyk   Boston Celtics      41        C   25     7-0
# 8              Terry Rozier   Boston Celtics      12       PG   22  06-Feb
# 9              Marcus Smart   Boston Celtics      36       PG   22  06-Apr
# 10          Jared Sullinger   Boston Celtics       7        C   24  06-Sep
# ...

# %%
a1.isnull().sum()
# Out:
# Name        0
# Team        0
# Number      0
# Position    0
# Age         0
# Height      0
# Weight      0
# College     0
# Salary      0
# dtype: int64

# %%
a1["Height"].head(10)
# Out:
# 0    06-Feb
# 1    06-Jun
# 2    06-May
# 3    06-May
# 4    06-Oct
# 5    06-Sep
# 6    06-Aug
# 7       7-0
# 8    06-Feb
# 9    06-Apr
# Name: Height, dtype: object

# %%
a1["Height"]=0
a1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      458 non-null    object
#  1   Team      458 non-null    object
#  2   Number    458 non-null    int64
#  3   Position  458 non-null    object
#  4   Age       458 non-null    int64
#  5   Height    458 non-null    int64
#  6   Weight    458 non-null    int64
#  7   College   458 non-null    object
#  8   Salary    458 non-null    float64
# dtypes: float64(1), int64(4), object(4)
# memory usage: 32.3+ KB

# %%
a1.head(10)
# Out:
#             Name            Team  Number Position  Age  Height  Weight  \
# 0  Avery Bradley  Boston Celtics       0       PG   25       0     180
# 1    Jae Crowder  Boston Celtics      99       SF   25       0     235
# 2   John Holland  Boston Celtics      30       SG   27       0     205
# 3    R.J. Hunter  Boston Celtics      28       SG   22       0     185
# 4  Jonas Jerebko  Boston Celtics       8       PF   29       0     231
# 5   Amir Johnson  Boston Celtics      90       PF   29       0     240
# 6  Jordan Mickey  Boston Celtics      55       PF   21       0     235
# 7   Kelly Olynyk  Boston Celtics      41        C   25       0     238
# 8   Terry Rozier  Boston Celtics      12       PG   22       0     190
# 9   Marcus Smart  Boston Celtics      36       PG   22       0     220
#
#              College      Salary
# 0              Texas   7730337.0
# 1          Marquette   6796117.0
# 2  Boston University         0.0
# 3      Georgia State   1148640.0
# ...

# %%
a2=a1
a2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      458 non-null    object
#  1   Team      458 non-null    object
#  2   Number    458 non-null    int64
#  3   Position  458 non-null    object
#  4   Age       458 non-null    int64
#  5   Height    458 non-null    int64
#  6   Weight    458 non-null    int64
#  7   College   458 non-null    object
#  8   Salary    458 non-null    float64
# dtypes: float64(1), int64(4), object(4)
# memory usage: 32.3+ KB

# %%
a1['Height'] = np.random.randint(150, 181, size=len(a2))
a1
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25     156     180
# 1      Jae Crowder  Boston Celtics      99       SF   25     169     235
# 2     John Holland  Boston Celtics      30       SG   27     171     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22     162     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29     168     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26     158     203
# 454      Raul Neto       Utah Jazz      25       PG   24     173     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26     150     256
# 456    Jeff Withey       Utah Jazz      24        C   26     165     231
# 457       Priyanka       Utah Jazz      34        C   25     173     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
a1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      458 non-null    object
#  1   Team      458 non-null    object
#  2   Number    458 non-null    int64
#  3   Position  458 non-null    object
#  4   Age       458 non-null    int64
#  5   Height    458 non-null    int32
#  6   Weight    458 non-null    int64
#  7   College   458 non-null    object
#  8   Salary    458 non-null    float64
# dtypes: float64(1), int32(1), int64(3), object(4)
# memory usage: 30.5+ KB

# %%
a1.describe()
# Out:
#            Number         Age      Height      Weight        Salary
# count  458.000000  458.000000  458.000000  458.000000  4.580000e+02
# mean    17.713974   26.934498  165.093886  221.543668  4.717870e+06
# std     15.966837    4.400128    9.250580   26.343200  5.216222e+06
# min      0.000000   19.000000  150.000000  161.000000  0.000000e+00
# 25%      5.000000   24.000000  157.000000  200.000000  1.000000e+06
# 50%     13.000000   26.000000  165.500000  220.000000  2.647980e+06
# 75%     25.000000   30.000000  173.000000  240.000000  6.323553e+06
# max     99.000000   40.000000  180.000000  307.000000  2.500000e+07

# %%
a1.tail()
# Out:
#              Name       Team  Number Position  Age  Height  Weight  \
# 453  Shelvin Mack  Utah Jazz       8       PG   26     158     203
# 454     Raul Neto  Utah Jazz      25       PG   24     173     179
# 455  Tibor Pleiss  Utah Jazz      21        C   26     150     256
# 456   Jeff Withey  Utah Jazz      24        C   26     165     231
# 457      Priyanka  Utah Jazz      34        C   25     173     231
#
#         College     Salary
# 453      Butler  2433333.0
# 454  No College   900000.0
# 455  No College  2900000.0
# 456      Kansas   947276.0
# 457      Kansas   947276.0

# %%
#1.How many are there in each Team and the percentage splitting with respect to the total employees

# %%
Teamcount=a1.Team.value_counts()
persplit=Teamcount/len(a1)*100
print(f"Team Counts are:{Teamcount}\n")
print(f"the percentage splitting with respect to the total employees:{persplit}")
# Out:
# Team Counts are:Team
# New Orleans Pelicans      19
# Memphis Grizzlies         18
# Utah Jazz                 16
# New York Knicks           16
# Milwaukee Bucks           16
# Brooklyn Nets             15
# Portland Trail Blazers    15
# Oklahoma City Thunder     15
# Denver Nuggets            15
# Washington Wizards        15
# Miami Heat                15
# Charlotte Hornets         15
# Atlanta Hawks             15
# San Antonio Spurs         15
# Houston Rockets           15
# Boston Celtics            15
# Indiana Pacers            15
# Detroit Pistons           15
# Cleveland Cavaliers       15
# Chicago Bulls             15
# Sacramento Kings          15
# Phoenix Suns              15
# Los Angeles Lakers        15
# Los Angeles Clippers      15
# Golden State Warriors     15
# Toronto Raptors           15
# Philadelphia 76ers        15
# Dallas Mavericks          15
# Orlando Magic             14
# Minnesota Timberwolves    14
# Name: count, dtype: int64
#
# ...

# %%
a1=pd.DataFrame(a1.Team.value_counts())
a1
# Out:
#                         count
# Team
# New Orleans Pelicans       19
# Memphis Grizzlies          18
# Utah Jazz                  16
# New York Knicks            16
# Milwaukee Bucks            16
# Brooklyn Nets              15
# Portland Trail Blazers     15
# Oklahoma City Thunder      15
# Denver Nuggets             15
# Washington Wizards         15
# Miami Heat                 15
# Charlotte Hornets          15
# Atlanta Hawks              15
# San Antonio Spurs          15
# Houston Rockets            15
# Boston Celtics             15
# Indiana Pacers             15
# Detroit Pistons            15
# Cleveland Cavaliers        15
# Chicago Bulls              15
# Sacramento Kings           15
# Phoenix Suns               15
# Los Angeles Lakers         15
# Los Angeles Clippers       15
# Golden State Warriors      15
# Toronto Raptors            15
# Philadelphia 76ers         15
# Dallas Mavericks           15
# Orlando Magic              14
# Minnesota Timberwolves     14

# %%
a1.plot.pie(y="count",figsize=(8,8),autopct='%1.1f%%', startangle=90, radius=1.2)
plt.legend(bbox_to_anchor=(1.5, 1), loc='upper left')
plt.show()

# %%
#2.Segregate the employees w.r.t different positions.

# %%
a1["Position"].value_counts()
# Out:
# Position
# SG    102
# PF    100
# PG     92
# SF     85
# C      79
# Name: count, dtype: int64

# %%
position_group=a1.groupby("Position")
for position,group in position_group:
   print(group)
# Out:
#                 Name                    Team  Number Position  Age  Height  \
# 7       Kelly Olynyk          Boston Celtics      41        C   25     174
# 10   Jared Sullinger          Boston Celtics       7        C   24     177
# 14      Tyler Zeller          Boston Celtics      44        C   26     171
# 23       Brook Lopez           Brooklyn Nets      11        C   28     174
# 27        Henry Sims           Brooklyn Nets      14        C   26     178
# ..               ...                     ...     ...      ...  ...     ...
# 439    Mason Plumlee  Portland Trail Blazers      24        C   26     174
# 447      Rudy Gobert               Utah Jazz      27        C   23     153
# 455     Tibor Pleiss               Utah Jazz      21        C   26     150
# 456      Jeff Withey               Utah Jazz      24        C   26     165
# 457         Priyanka               Utah Jazz      34        C   25     173
#
#      Weight         College      Salary
# ...

# %%
a1.isnull().sum()
# Out:
# Name        0
# Team        0
# Number      0
# Position    0
# Age         0
# Height      0
# Weight      0
# College     0
# Salary      0
# dtype: int64

# %%
#3.Find from which age group most of the employees belong to

# %%
age=a1['Age'].value_counts().head(30)
age
# Out:
# Age
# 24    47
# 25    46
# 27    41
# 23    41
# 26    36
# 28    31
# 30    31
# 29    28
# 22    26
# 31    22
# 20    19
# 21    19
# 33    14
# 32    13
# 34    10
# 36    10
# 35     9
# 37     4
# 38     4
# 40     3
# 39     2
# 19     2
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,6))
sns.countplot(x="Age",data=a1)
plt.title("Age Group Category")
plt.show()

# %%
bins= [15,20,25,30,35,40]
labels=["15-20","21-25","26-30","31-35","36-40"]
a1["Age_Group"]=pd.cut(a1["Age"],bins=bins,labels=labels)
sns.countplot(x="Age_Group",data=a1)
plt.title("Age Group Category")
plt.show()

# %%
a1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Name       458 non-null    object
#  1   Team       458 non-null    object
#  2   Number     458 non-null    int64
#  3   Position   458 non-null    object
#  4   Age        458 non-null    int64
#  5   Height     458 non-null    int32
#  6   Weight     458 non-null    int64
#  7   College    458 non-null    object
#  8   Salary     458 non-null    float64
#  9   Age_Group  458 non-null    category
# dtypes: category(1), float64(1), int32(1), int64(3), object(4)
# memory usage: 31.2+ KB

# %%
#4. Find out under which team and position, spending in terms of salary is high.

# %%
Team_salary=a1.groupby(["Team","Position"])["Salary"].sum()
Team_salary
# Out:
# Team                Position
# Atlanta Hawks       C           22756250.0
#                     PF          23952268.0
#                     PG           9763400.0
#                     SF           6000000.0
#                     SG          10431032.0
#                                    ...
# Washington Wizards  C           24490429.0
#                     PF          11300000.0
#                     PG          18022415.0
#                     SF          11158800.0
#                     SG          11356992.0
# Name: Salary, Length: 149, dtype: float64

# %%
Team_salary.sort_values().tail()
# Out:
# Team                Position
# Denver Nuggets      SF          27982771.0
# Phoenix Suns        PG          28002998.0
# Houston Rockets     SG          28122883.0
# Miami Heat          PF          31538671.0
# Los Angeles Lakers  SF          31866445.0
# Name: Salary, dtype: float64

# %%
highest=Team_salary.max()
highest
highest_spending=Team_salary.loc[Team_salary==highest]
print(f"Team and position, spending in terms of salary is high :{highest_spending}")
# Out:
# Team and position, spending in terms of salary is high :Team                Position
# Los Angeles Lakers  SF          31866445.0
# Name: Salary, dtype: float64

# %%
#5.Find if there is any correlation between age and salary , represent it visually.

# %%
sns.scatterplot(x="Age",y="Salary",data=a1)
plt.xlabel("Age",color='r')
plt.ylabel("Salary",color='r')
plt.xticks([18,20,22,24,26,28,30,32,34,36,38,40])
plt.title("Correlation Between Age & Salary",color='r')
plt.show()

# %%
a1
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25     156     180
# 1      Jae Crowder  Boston Celtics      99       SF   25     169     235
# 2     John Holland  Boston Celtics      30       SG   27     171     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22     162     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29     168     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26     158     203
# 454      Raul Neto       Utah Jazz      25       PG   24     173     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26     150     256
# 456    Jeff Withey       Utah Jazz      24        C   26     165     231
# 457       Priyanka       Utah Jazz      34        C   25     173     231
#
#                College     Salary Age_Group
# 0                Texas  7730337.0     21-25
# ...

# %%
a1.isnull().sum()
# Out:
# Name         0
# Team         0
# Number       0
# Position     0
# Age          0
# Height       0
# Weight       0
# College      0
# Salary       0
# Age_Group    0
# dtype: int64

# %%
a1.to_csv("JAModulEndProject.csv")
